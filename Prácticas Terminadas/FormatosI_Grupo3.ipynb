# %% [markdown]
# ### Práctica de Formatos de datos: CSV y JSON

# %%
# Víctor Fernández Rubio
# David González Jiménez
# Carlos Llames Arribas
# Marta Pastor Puente

# %% [markdown]
# #### Ejercicio 1[5 puntos]
# Considerar los archivos __Terrazas.csv__ y __Locales.csv__ que contiene un censo de locales y actividades del Ayuntamiento de Madrid, clasificados según su tipo de acceso (puerta de calle o agrupado), situación (abierto, cerrado...) e indicación de la actividad económica ejercida y de las terrazas de hostelería y restauración que aparecen registradas en dicho censo. Observar que la información puede contener alguna inconsistencia.Se pide realizar funciones en Python que permitan realizar las siguientes acciones:
#
# * Usando los dos archivos indicados, se pide crear un nuevo archivo csv denominados __NoTerrazas.csv__ el cual contenga la información de los locales que no son terrazas. Es decir, contendrá la misma información que el archivo __Locales.csv__ pero sin la información de locales que son Terrazas.
#
# * Usando el archivo __Locales.csv__ se pide crear una nuevo archivo csv denominada __Agrupadas.csv__ el cual debe contener una línea por cada barrio conteniendo el número de locales en los que el nombre del vial del edificio en que se encuentran es diferente del nombre del vial de acceso al local. Por ejemplo el local con id 10000401 se encuentra en la Plaza de Isabel II pero el acceso al mismo se realiza desde la Calle Arenal. La información en el archivo debe aparecer en el siguiente orden:
#
#   Código Barrio, Nombre Barrio, Número de empresas cumpliendo la condición
#
#
#
# * Usando el archivo __Terrazas.csv__ crea un nuevo archivo cvs denominado TopRepeticiones.cvs. Considera el número de veces que se repite el nombre de una terraza (campo rótulo). Se pide crear un archivo csv que contenga los 20 nombres que más se repiten. La información en el archivo debe aparecer en orden descendente con los siguientes campos de información:
#
#   Nombre terraza, Número de repeticiones

# %% [markdown]
# Para leer los archivos usa un código como el siguiente:

# %% [raw]
# import csv
# csvarchivo = open('Locales.csv',encoding="utf8",errors='ignore')
# entrada = csv.reader(csvarchivo, delimiter=";")

# %%
# NoTerrazas.csv

import csv
import operator

if __name__ == "__main__":
    # We use try-except statements to properly handle errors, as in case the
    # input file does not exist in the directory.
    try:
        # We open the .csv file loading the filds separated by a ; delimiter:
        csv_archivo_locales = open("Locales.csv", encoding="utf8", errors='ignore')
        locales = csv.reader(csv_archivo_locales, delimiter=";")
        csv_archivo_terrazas = open("Terrazas.csv", encoding="utf8", errors='ignore')
        terrazas = csv.reader(csv_archivo_terrazas, delimiter=";")

        # We skip the first line before saving the results into a list for later
        # processing by using the next() statement. The reason why we do not use
        # the line_num function is because we would need to include it in a loop
        # and read file line by line whereas this way, with just two instructions
        # we get the same result:
        next(locales, None)
        lista_locales = list(locales)
        next(terrazas, None)
        lista_terrazas = list(terrazas)

        # When we read the fields from the CSV, they are stored as strings, so we
        # need to explicitely convert the ID to int to be able to sort them:
        for i in lista_locales:
            i[0] = int(i[0])

        for j in lista_terrazas:
            j[0] = int(j[0])

        # We sort the lists taking into account the ID column which is in the
        # first position to get it with the itemergetter function:
        sorted_lista_locales = sorted(lista_locales, key=operator.itemgetter(0), reverse = False)
        sorted_lista_terrazas = sorted(lista_terrazas, key=operator.itemgetter(0), reverse = False)

        # For each entry in lista_terrazas, we check where is its corresponding
        # entry in lista_locales. As they are sorted ascendently, all the entries
        # before the wanted one are included in the result list as they do not
        # appear in lista_terrazas. Moreover, we keep the index counter to just
        # traverse the lista_locales once.
        index = 0
        no_terrazas = []
        for terraza in sorted_lista_terrazas:
            while (terraza[0] > sorted_lista_locales[index][0]):
                no_terrazas.append(sorted_lista_locales[index])
                index += 1

            # It is important to perform this step once we have reached the local
            # entry from the lista_locales, as if not, the next entry from
            # lista_terrazas will be greater than the found one in lista_locales
            # and will wrongly include it in the result list:
            if (terraza[0] == sorted_lista_locales[index][0]):
                index += 1

        # We open the output file to store the data retrieved:
        csvFileObj = open("NoTerrazas.csv", "w")
        csvWriter = csv.writer(csvFileObj, delimiter=";")

        # For each row in the final list, we write it to the CSV output file:
        for row in no_terrazas:
            csvWriter.writerow(row)
            
        print ("The file has been successfully created.")

        # We close the opened CSV file:
        csvFileObj.close()

        # NOTE: we have realized that a few error occurs when comparing the total
        # amount of entries in NoTerrazas.csv with the entries in Locales.csv and
        # Terrazas.csv, as it is expected to have NoTerrazas = Locales - Terrazas

        # However, as the exercice statement indicates that some inconsistency
        # may exist in the files, we assume the error is due to this unsteadiness.

    except IOError:
        print("The file does not exist.")
# Out:
# The file has been successfully created.

# %%
# Agrupadas.csv
import csv

if __name__ == "__main__":
    # We use try-except statements to properly handle errors, as in case the
    # input file does not exist in the directory.
    try:
        # We open the .csv file loading the filds separated by a ; delimiter:
        csv_archivo_locales = open("Locales.csv", encoding="utf8", errors='ignore')
        entrada_locales = csv.reader(csv_archivo_locales, delimiter=";")

        # We skip the first line before saving the results into a list for later
        # processing by using the next() statement. The reason why we do not use
        # the line_num function is because we would need to include it in a loop
        # and read file line by line whereas this way, with just two instructions
        # we get the same result:
        next(entrada_locales, None)
        lista_locales = list(entrada_locales)

        # List that will contain the result:
        agrupadas = []
        # Dictionary to keep the relation of neighborhood ID and its name, and
        # the number of locals whose main entry address differs from its official
        # address:
        barrios_dic = {}

        # For each local in the list of locals, we check if it is already in the
        # dictionary to increase its counter. Otherwise, we create a new entry in
        # the dictionary and set the counter to 1:
        for local in lista_locales:
            if local[16] != local[25]:
                entry = local[3] + ',' + local[4]

                if entry in barrios_dic:
                    barrios_dic[entry] += 1
                else:
                    barrios_dic[entry] = 1

        # Now we get the key (neighborhood ID + neighborhood name) and its attached
        # value (counter). To split the key into the two different fields it is
        # containing, we use the split() function and store the fields in a
        # small list also with the counter value:
        for key, value in barrios_dic.items():
            lista_barrios = []
            info_barrio = key.split(',')

            for i in info_barrio:
                lista_barrios.append(i)
            lista_barrios.append(value)

            # Finally, we store the mini-list containing the requested information
            # for each neighborhood in a list of neighborhoods:
            agrupadas.append(lista_barrios)

        # We open the output file to store the data retrieved:
        csvFileObj = open("Agrupadas.csv", "w")
        csvWriter = csv.writer(csvFileObj, delimiter=";")

        # For each row in the final list, we write it to the CSV output file:
        for row in agrupadas:
            csvWriter.writerow(row)
            
        print ("The file has been successfully created.")

        # We close the opened CSV file:
        csvFileObj.close()

    except IOError:
        print("The file does not exist.")
# Out:
# The file has been successfully created.

# %%
# TopRepeticiones.csv
import csv
import operator

if __name__ == "__main__":
    # We use try-except statements to properly handle errors, as in case the
    # input file does not exist in the directory.
    try:
        # We open the .csv file loading the filds separated by a ; delimiter:
        csv_archivo_terrazas = open("Terrazas.csv", encoding="utf8", errors='ignore')
        terrazas = csv.reader(csv_archivo_terrazas, delimiter=";")

        # We skip the first line before saving the results into a list for later
        # processing by using the next() statement. The reason why we do not use
        # the line_num function is because we would need to include it in a loop
        # and read file line by line whereas this way, with just two instructions
        # we get the same result:
        next(terrazas, None)
        lista_terrazas = list(terrazas)

        # Dictionary to keep the relation of local banner text and the number of
        # locals whith the same banner name:
        terrazas_dic = {}

        # For each local in the list of locals, we check if it is already in the
        # dictionary to increase its counter. Otherwise, we create a new entry in
        # the dictionary and set the counter to 1:
        for terraza in lista_terrazas:
            entry = terraza[21]

            if entry in terrazas_dic:
                terrazas_dic[entry] += 1
            else:
                terrazas_dic[entry] = 1

        # Now we get the key (local banner text) and its attached value (counter).
        # Then we store both values in a mini-list which will be also store in a
        # list of lists (each of one of those lists containing the values banner
        # text and amount of times it is repeated among all the locals):
        lista_rotulos = []
        for key,value in terrazas_dic.items():
            lista_num_rotulos = []

            lista_num_rotulos.append(key)
            lista_num_rotulos.append(value)

            lista_rotulos.append(lista_num_rotulos)

        # We sort the list taking into account the counting column which is in
        # the second position to get it with the itemergetter function:
        sorted_list_rotulos = sorted(lista_rotulos, key=operator.itemgetter(1), reverse = True)

        # Finally, we store in the result list only the first 20 values, already
        # sorted in descented mode:
        top_repeticiones = []
        for i in range(0, 20):
            top_repeticiones.append(sorted_list_rotulos[i])

        # We open the output file to store the data retrieved:
        csvFileObj = open("TopRepeticiones.csv", "w")
        csvWriter = csv.writer(csvFileObj, delimiter=";")

        # For each row in the final list, we write it to the CSV output file:
        for row in top_repeticiones:
            csvWriter.writerow(row)
            
        print ("The file has been successfully created.")

        # We close the opened CSV file:
        csvFileObj.close()

    except IOError:
        print("The file does not exist.")
# Out:
# The file has been successfully created.

# %% [markdown]
# #### Ejercicio 2[5 puntos]
# Considerar el archivo __Agenda.json__ que contiene información de actividades de carácter gratuito, para público infantil y adulto, desarrolladas por las siguientes instituciones de titularidad municipal: la red de Bibliotecas Públicas, la Biblioteca Histórica, la Biblioteca Musical Víctor Espinós, la Hemeroteca y la Imprenta. Se presentan las actividades de los próximos 60 dias. Se pide realizar funciones en Python que permitan realizar las siguientes acciones:
#
# * El archivo contiene un campo denominado "audience" que indica el público al que va dirigido. A veces aparece y otras veces no aparece dicho campo. Se quiere procesar el archivo para obtener como resultado dos archivos de texto:el archivo __Niños.txt__ que contendrá la información de los eventos que es exclusivamente para niños y el archivo __Familias.txt__ que contendrá la información de los eventos que está dirigida a niños y familias. En los archivos debe aparecer una línea por cada evento cumpliendo las condiciones indicadas, y mostrando la información siguiente:
#
#    Título del evento(campo title), inicio(campo "dtstart"), finalizacion(campo "dtend"), url(campo link)
#
#
# * Se desea conocer los eventos más cercanos a un punto que viene especificado por su longitud y latitud. De manera que se quiere crear una función que tomando como entrada una longitud, una latitud y un número real que representa una distancia en kilometros, devuelva como resultado los eventos que se encuentran a una distancia menor o igual a la distancia dada como parámetro. El resultado se mostrará por la pantalla mostrando una línea por cada evento. De cada evento se mostrará:
#
#   Título del evento(campo title), inicio(campo "dtstart"), finalizacion(campo "dtend"), url(campo link)
#
# Para calcular la distancia entre dos puntos dadas sus coordenadas se utilizará la siguiente función en Python:

# %% [raw]
# import math
#
# def haversine(lat1, lon1, lat2, lon2):
#     rad=math.pi/180
#     dlat=lat2-lat1
#     dlon=lon2-lon1
#     R=6372.795477598
#     a=(math.sin(rad*dlat/2))**2 + math.cos(rad*lat1)*math.cos(rad*lat2)*(math.sin(rad*dlon/2))**2
#     distancia=2*R*math.asin(math.sqrt(a))
#     return distancia

# %% [markdown]
# Para leer los archivos usa un código como el siguiente:

# %% [raw]
# import json
# leer = json.loads(open('Agenda.json',encoding="utf8").read())

# %%
# Audience
import json

if __name__ == "__main__":
    # We use try-except statements to properly handle errors, as in case the
    # input file does not exist in the directory.
    try:
        # We open the .json file and properly load it in JSON format using the
        # json module for Python
        doc = open('Agenda.json', encoding="utf8")
        json_doc = json.loads(doc.read())
        lista_eventos = json_doc["@graph"]

        try:
            # We open both the output files to store the data retrieved
            kids = open("Children.txt", "w", encoding="utf8")
            familias = open("Families.txt", "w", encoding="utf8")

            # For each entry in the list of events, we check if the field
            # "audience" corresponds to one of the ones we are looking for. If
            # it is the case, we add it to the correspondent output file:
            for evento in lista_eventos:
                if "audience" in evento:
                    if evento["audience"] == "Niños,Familias":
                        familias.write("Titulo: " + evento["title"] + "; " + "Inicio: " + evento["dtstart"] + "; " + "Final: " + evento["dtend"] + "; " + "URL: " + evento["link"] + "\n")
                    elif evento["audience"] == "Niños":
                        kids.write("Titulo: " + evento["title"] + "; " + "Inicio: " + evento["dtstart"] + "; " + "Final: " + evento["dtend"] + "; " + "URL: " + evento["link"] + "\n")

            print ("The files have been successfully created.")

            # We close every opened file:
            kids.close()
            familias.close()
            doc.close()

        except IOError:
            print ("The files could not be opened.")

    except IOError:
        print("The file does not exist.")
# Out:
# The files have been successfully created.

# %%
# Distance
import json
import math

def haversine(lat1, lon1, lat2, lon2):
    rad=math.pi/180
    dlat= lat2 - lat1
    dlon= lon2 - lon1
    R=6372.795477598
    a=(math.sin(rad*dlat/2))**2 + math.cos(rad*lat1)*math.cos(rad*lat2)*(math.sin(rad*dlon/2))**2
    distancia=2*R*math.asin(math.sqrt(a))
    return distancia


def eventos_cercanos(latitud, longitud, max_distancia, json_doc):
    lista_eventos = json_doc["@graph"]

    # For every event in the list of events, we obtain its latitude and longitude
    # and calculate the distance in km using the given function.
    for loc in lista_eventos:
        if "location" in loc:
            lat = loc["location"]["latitude"]
            lon = loc["location"]["longitude"]
            dis = haversine(float(latitud), float(longitud), lat ,lon)

            # If the distance calculated is lower than our maximun distance wanted
            # then the activity is shown in the standard output:
            if dis <= float(max_distancia):
                print ("Titulo: " + loc["title"] + "; " + "Inicio: " + loc["dtstart"] + "; " + "Final: " + loc["dtend"] + "; " + "URL: " + loc["link"] + "\n")


if __name__ == "__main__":
    # We use try-except statements to properly handle errors, as in case the
    # input file does not exist in the directory.
    try:
        # We open the .json file and properly load it in JSON format using the
        # json module for Python
        doc = open('Agenda.json', encoding="utf8")
        json_doc = json.loads(doc.read())

        lista_eventos = json_doc["@graph"]

        # We introduce the desired values to calculate from:
        miLat = input ("Mi latitud: \n")
        miLon = input ("Mi longitud: \n")
        distMax = input ("Distancia maxima que recorrer: \n")

        eventos_cercanos(miLat, miLon, distMax, json_doc)

        # We close the opened file:
        doc.close()

    except IOError:
        print("The file does not exist.")
# Out:
# Mi latitud:
# 40
# Mi longitud:
# -3
# Distancia maxima que recorrer:
# 80
# Titulo: A medias; Inicio: 2017-10-22 19:00:00.0; Final: 2017-10-22 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ad3b9c7bd059e510VgnVCM1000001d4a900aRCRD
#
# Titulo: American Cultural Bites; Inicio: 2017-10-27 19:00:00.0; Final: 2017-10-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c34634b9e7cde510VgnVCM2000001f4a900aRCRD
#
# Titulo: Bambi; Inicio: 2017-10-30 18:00:00.0; Final: 2017-10-30 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c86f1fcc397ce510VgnVCM2000001f4a900aRCRD
#
# Titulo: Bebecuentos con Carlos Alba; Inicio: 2017-12-04 17:30:00.0; Final: 2017-12-04 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c1a0121bd69be510VgnVCM1000001d4a900aRCRD
#
# Titulo: Biblioajedrez; Inicio: 2017-09-19 18:30:00.0; Final: 2018-06-26 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=287f8f00c7a9e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Bicentenario de los caprichos Románticos de Fernando VII; Inicio: 2017-10-26 19:00:00.0; Final: 2017-10-26 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=91cdecaf1e60f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Café Científico. Crispr cas; Inicio: 2017-11-30 19:00:00.0; Final: 2017-11-30 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b50a2cf11c58e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Café Científico. La ciudadanía ha hablado; Inicio: 2017-12-14 19:00:00.0; Final: 2017-12-14 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=323a2cf11c58e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Café Científico. ¿Es posible envejecer saludablemente?; Inicio: 2017-10-26 19:00:00.0; Final: 2017-10-26 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a8d92cf11c58e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Cata de libros. El amor y el desamor.; Inicio: 2017-10-21 11:30:00.0; Final: 2017-10-21 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=184e3f79522ee510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cata de libros. La familia; Inicio: 2017-10-24 18:30:00.0; Final: 2017-10-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=277a0ddba9a2f510VgnVCM1000001d4a900aRCRD
#
# Titulo: Chap, chap, ...plash con Alicia Mohino; Inicio: 2017-11-20 17:30:00.0; Final: 2017-11-20 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=aa3c121bd69be510VgnVCM1000001d4a900aRCRD
#
# Titulo: Chap, chap, ...plash con Alicia Mohino; Inicio: 2017-11-13 17:30:00.0; Final: 2017-11-13 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=58cb121bd69be510VgnVCM1000001d4a900aRCRD
#
# Titulo: Chap, chap, ...plash con Alicia Mohino; Inicio: 2017-12-04 17:30:00.0; Final: 2017-12-04 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=3e9e121bd69be510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cinefórum 'María querida'; Inicio: 2017-10-20 18:00:00.0; Final: 2017-10-20 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ec8e5a1872cee510VgnVCM1000001d4a900aRCRD
#
# Titulo: Club de lectura; Inicio: 2017-10-05 10:30:00.0; Final: 2018-05-31 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=aae3fc8e3215e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Club de lectura literatura juvenil; Inicio: 2017-10-06 19:00:00.0; Final: 2018-05-25 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=f9bafc8e3215e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cocinando cuentos con Primigenius; Inicio: 2017-11-06 17:30:00.0; Final: 2017-11-06 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=550c121bd69be510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cocinando cuentos con Primigenius; Inicio: 2017-12-04 17:30:00.0; Final: 2017-12-04 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2cde121bd69be510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cocinando cuentos con Primigenius; Inicio: 2017-11-07 18:00:00.0; Final: 2017-11-07 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b11fc686ebe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cocinando cuentos con Primigenius; Inicio: 2017-10-31 18:00:00.0; Final: 2017-10-31 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a7f3b6008fe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cocinando cuentos con Primigenius; Inicio: 2017-11-22 18:00:00.0; Final: 2017-11-22 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=f4e221dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cocinando cuentos con Primigenius; Inicio: 2017-11-17 18:00:00.0; Final: 2017-11-17 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=5e0b21dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cocinando cuentos con Primigenius; Inicio: 2017-10-19 18:00:00.0; Final: 2017-10-19 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8d2421dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cocinando cuentos con Primigenius; Inicio: 2017-12-01 18:00:00.0; Final: 2017-12-01 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=5208c686ebe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cocinando cuentos con Primigenius; Inicio: 2017-11-02 18:00:00.0; Final: 2017-11-02 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=10a498df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cocinando cuentos con Primigenius; Inicio: 2017-11-23 18:00:00.0; Final: 2017-11-23 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=70b8bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: CoderDojo; Inicio: 2017-10-08 09:30:00.0; Final: 2018-06-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=20da05b07f89e510VgnVCM1000001d4a900aRCRD
#
# Titulo: CoderDojo en la Biblioteca María Lejárraga; Inicio: 2017-10-21 12:00:00.0; Final: 2018-01-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6d91e313af00f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Coloquio taller de edición; Inicio: 2017-11-14 19:00:00.0; Final: 2017-11-14 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a1e9121bd69be510VgnVCM1000001d4a900aRCRD
#
# Titulo: Comunicación; Inicio: 2017-10-10 18:00:00.0; Final: 2017-10-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=93853aa2b8dce510VgnVCM1000001d4a900aRCRD
#
# Titulo: Constelaciones familiares; Inicio: 2017-10-25 11:00:00.0; Final: 2017-10-25 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a89d062967d1a510VgnVCM2000001f4a900aRCRD
#
# Titulo: Corazón de tinta; Inicio: 2017-10-24 18:00:00.0; Final: 2017-10-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=372305e0137ce510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuarto y mitad: concurso literario; Inicio: 2017-10-01 00:00:00.0; Final: 2017-11-07 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=560ea4eda88ce510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos bufonescos con Juan Gamba; Inicio: 2017-11-21 18:00:00.0; Final: 2017-11-21 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=566fc686ebe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos bufonescos con Juan Gamba; Inicio: 2017-10-25 18:00:00.0; Final: 2017-10-25 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6046b6008fe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos bufonescos con Juan Gamba; Inicio: 2017-12-15 18:00:00.0; Final: 2017-12-15 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=42f098df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos bufonescos con Juan Gamba; Inicio: 2017-10-19 18:00:00.0; Final: 2017-10-19 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=f10298df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos bufonescos con Juan Gamba; Inicio: 2017-11-16 18:00:00.0; Final: 2017-11-16 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=cfd498df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos bufonescos con Juan Gamba; Inicio: 2017-12-17 12:00:00.0; Final: 2017-12-17 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=faaeab562631e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Cuentos bufonescos con Juan Gamba; Inicio: 2017-10-31 18:00:00.0; Final: 2017-10-31 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a4df21dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos con Carlos Alba; Inicio: 2017-12-07 18:00:00.0; Final: 2017-12-07 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=7f45bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos de enredos y travesuras con Nelso Calderon; Inicio: 2017-11-19 12:00:00.0; Final: 2017-11-19 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=680eab562631e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Cuentos de enredos y travesuras con Nelson Calderón; Inicio: 2017-11-03 18:00:00.0; Final: 2017-11-03 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c1adeeb6482ee510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos de enredos y travesuras con Nelson Calderón; Inicio: 2017-11-28 18:00:00.0; Final: 2017-11-28 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2051bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos de enredos y travesuras con Nelson Calderón; Inicio: 2017-11-16 18:00:00.0; Final: 2017-11-16 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=13724410571fe510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos de enredos y travesuras con Nelson Calderón; Inicio: 2017-12-14 18:00:00.0; Final: 2017-12-14 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=e8e298df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos de enredos y travesuras con Nelson Calderón; Inicio: 2017-10-25 18:00:00.0; Final: 2017-10-25 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c4a3562d96e0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos de enredos y travesuras con Nelson Calderón; Inicio: 2017-11-02 18:00:00.0; Final: 2017-11-02 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=f69e98df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos de enredos y travesuras con Nelson Calderón; Inicio: 2017-11-21 18:00:00.0; Final: 2017-11-21 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ca41562d96e0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos de enredos y travesuras con Nelson Calderón; Inicio: 2017-10-26 18:00:00.0; Final: 2017-10-26 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b54498df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos infantiles en la Biblioteca Pública Municipal La Chata; Inicio: 2017-11-24 18:00:00.0; Final: 2017-11-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8e6b21dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos infantiles en la Biblioteca Pública Municipal La Chata; Inicio: 2017-12-15 18:00:00.0; Final: 2017-12-15 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=13cb21dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos infantiles en la Biblioteca Pública Municipal La Chata; Inicio: 2017-10-27 18:00:00.0; Final: 2017-10-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=63da21dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos por las ramas con Alicia Mohíno; Inicio: 2017-11-14 17:30:00.0; Final: 2017-11-14 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=553d121bd69be510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos por las ramas con Alicia Mohíno; Inicio: 2017-11-06 17:30:00.0; Final: 2017-11-06 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=233d121bd69be510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos por las ramas con Alicia Mohino; Inicio: 2017-11-30 18:00:00.0; Final: 2017-11-30 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=9073c686ebe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos por las ramas con Alicia Mohino; Inicio: 2017-10-19 18:00:00.0; Final: 2017-10-19 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=df5e98df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos por las ramas con Alicia Mohino; Inicio: 2017-11-16 18:00:00.0; Final: 2017-11-16 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=f39298df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos por las ramas con Alicia Mohíno; Inicio: 2017-11-28 18:00:00.0; Final: 2017-11-28 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6f86bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Cuentos por las ramas con Alicia Mohíno; Inicio: 2017-11-28 18:00:00.0; Final: 2017-11-28 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ec77b053322ee510VgnVCM2000001f4a900aRCRD
#
# Titulo: Curso de mecánica y conducción de bicicletas; Inicio: 2017-09-22 17:30:00.0; Final: 2017-11-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=540610e21ac9c510VgnVCM2000001f4a900aRCRD
#
# Titulo: Día de la Biblioteca; Inicio: 2017-10-02 08:30:00.0; Final: 2017-10-28 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=e070fdb13f1ce510VgnVCM1000001d4a900aRCRD
#
# Titulo: Editatona en la  Biblioteca Miguel Delibes; Inicio: 2017-11-22 10:00:00.0; Final: 2017-11-22 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=e27f2c0856cee510VgnVCM1000001d4a900aRCRD
#
# Titulo: Editatona en la Biblioteca Ana María Matute; Inicio: 2017-10-24 10:00:00.0; Final: 2017-10-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=fdcd2c0856cee510VgnVCM1000001d4a900aRCRD
#
# Titulo: Editores a tumba abierta, dispare al editor; Inicio: 2017-10-19 18:00:00.0; Final: 2017-10-19 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=19a755b732ebe510VgnVCM2000001f4a900aRCRD
#
# Titulo: Educación integral en sexualidad y relaciones de pareja.; Inicio: 2017-10-02 18:30:00.0; Final: 2017-11-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c20d2ff22399e510VgnVCM2000001f4a900aRCRD
#
# Titulo: El cine: la lengua escrita de la realidad; Inicio: 2017-11-14 19:00:00.0; Final: 2017-11-14 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ecd2fad10452f510VgnVCM1000001d4a900aRCRD
#
# Titulo: El cine: la lengua escrita de la realidad; Inicio: 2017-12-12 19:00:00.0; Final: 2017-12-12 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d233fad10452f510VgnVCM1000001d4a900aRCRD
#
# Titulo: El cine: la lengua escrita de la realidad; Inicio: 2017-11-28 19:00:00.0; Final: 2017-11-28 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6913fad10452f510VgnVCM1000001d4a900aRCRD
#
# Titulo: El dragón que se comió el Sol con Daniel Tornero; Inicio: 2017-12-04 18:00:00.0; Final: 2017-12-04 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c2a2bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El dragón que se comió el Sol con Daniel Tornero; Inicio: 2017-10-31 18:00:00.0; Final: 2017-10-31 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=789d21dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El dragón que se comió el Sol con Daniel Tornero; Inicio: 2017-12-13 18:00:00.0; Final: 2017-12-13 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8f2321dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El dragón que se comió el sol con Daniel Tornero; Inicio: 2017-12-15 18:00:00.0; Final: 2017-12-15 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=99cdeeb6482ee510VgnVCM1000001d4a900aRCRD
#
# Titulo: El dragón que se comió el sol con Daniel Tornero; Inicio: 2017-10-20 18:00:00.0; Final: 2017-10-20 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=3666562d96e0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El dragón que se comió el Sol con Daniel Tornero; Inicio: 2017-11-21 18:00:00.0; Final: 2017-11-21 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d464bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El dragón que se comió el Sol con Daniel Tornero; Inicio: 2017-11-22 18:00:00.0; Final: 2017-11-22 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=91cebc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El dragón que se comió el Sol con Daniel Tornero; Inicio: 2017-12-12 18:00:00.0; Final: 2017-12-12 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=699021dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El fantasma al que le asustaban los libros con Nelson Calderón; Inicio: 2017-11-24 18:00:00.0; Final: 2017-11-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=3833bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El fantasma al que le asustaban los libros con Nelson Calderón; Inicio: 2017-10-19 18:00:00.0; Final: 2017-10-19 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a36721dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El fantasma al que le asustaban los libros con Nelson Calderón; Inicio: 2017-10-20 18:00:00.0; Final: 2017-10-20 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=44aa21dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El fantasma al que le asustaban los libros con Nelson Calderón; Inicio: 2017-12-01 18:00:00.0; Final: 2017-12-01 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=afa098df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El fantasma al que le asustaban los libros con Nelson Calderón; Inicio: 2017-11-07 18:00:00.0; Final: 2017-11-07 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0236bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El fantasma que asustaba a los cuentos con Nelson Calderón; Inicio: 2017-10-21 12:00:00.0; Final: 2017-10-21 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=da10ab562631e510VgnVCM2000001f4a900aRCRD
#
# Titulo: El iglú; Inicio: 2017-10-26 18:00:00.0; Final: 2017-10-26 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=1d88440e22ece510VgnVCM2000001f4a900aRCRD
#
# Titulo: El legado de las poetas del siglo XX; Inicio: 2017-10-20 19:00:00.0; Final: 2017-10-20 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=32befb0e07b0f510VgnVCM1000001d4a900aRCRD
#
# Titulo: El león Kandina con Boniface ofogo; Inicio: 2017-12-14 18:00:00.0; Final: 2017-12-14 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=da84c686ebe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El león Kandinga con Bonface Ofogo; Inicio: 2017-11-15 17:30:00.0; Final: 2017-11-15 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=63fc121bd69be510VgnVCM1000001d4a900aRCRD
#
# Titulo: El león Kandinga con Boniface; Inicio: 2017-11-03 18:00:00.0; Final: 2017-11-03 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=142098df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El león Kandinga con Boniface; Inicio: 2017-11-16 18:00:00.0; Final: 2017-11-16 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d7ce98df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El león Kandinga con Boniface Ofogo; Inicio: 2017-10-26 18:00:00.0; Final: 2017-10-26 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a982c686ebe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El león Kandinga con Boniface Ofogo; Inicio: 2017-12-12 18:00:00.0; Final: 2017-12-12 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a205bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El león Kandinga con Boniface Ofogo; Inicio: 2017-10-27 18:00:00.0; Final: 2017-10-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a66f3aa2b8dce510VgnVCM1000001d4a900aRCRD
#
# Titulo: El león Kandinga con Boniface Ofogo; Inicio: 2017-11-28 18:00:00.0; Final: 2017-11-28 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=765e21dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El león Kandinga con Boniface Ofogo; Inicio: 2017-12-02 12:00:00.0; Final: 2017-12-02 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=bbc0ab562631e510VgnVCM2000001f4a900aRCRD
#
# Titulo: El león Kandinga con Boniface Ofogo; Inicio: 2017-12-02 12:00:00.0; Final: 2017-12-02 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=cc6eab562631e510VgnVCM2000001f4a900aRCRD
#
# Titulo: El león Kandinga con Boniface Ofogo; Inicio: 2017-11-17 18:00:00.0; Final: 2017-11-17 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=4697562d96e0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El león Kandinga con Boniface Ofogo; Inicio: 2017-10-25 18:00:00.0; Final: 2017-10-25 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=5fc0b6008fe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El león Kandinga con Boniface Ofogo; Inicio: 2017-11-14 18:00:00.0; Final: 2017-11-14 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=4121bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El león Kandinga con Boniface Ofogo; Inicio: 2017-11-29 18:00:00.0; Final: 2017-11-29 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=5064562d96e0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El león Kandinga con Boniface Ofogo; Inicio: 2017-10-24 18:00:00.0; Final: 2017-10-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=538ec686ebe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El león Kandinga con Boniface Ofogo; Inicio: 2017-12-05 18:00:00.0; Final: 2017-12-05 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b822562d96e0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El León Kandinga con Boniface Ofogo; Inicio: 2017-10-26 18:00:00.0; Final: 2017-10-26 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=643298df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El león Kandinga con Boniface Ofogo; Inicio: 2017-11-30 18:00:00.0; Final: 2017-11-30 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=4a18bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El lobo que se cayó de un libro; Inicio: 2017-10-25 18:00:00.0; Final: 2017-10-25 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6bf8f6a3338ce510VgnVCM1000001d4a900aRCRD
#
# Titulo: El Mausoleo de Halicarnaso; Inicio: 2017-10-20 18:30:00.0; Final: 2017-10-20 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=1667dee6398be510VgnVCM1000001d4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-11-16 18:00:00.0; Final: 2017-11-16 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=24f2c686ebe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-11-30 18:00:00.0; Final: 2017-11-30 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ee1ac686ebe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-10-26 18:00:00.0; Final: 2017-10-26 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=81d721dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-11-14 18:00:00.0; Final: 2017-11-14 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=93dd21dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-11-15 18:00:00.0; Final: 2017-11-15 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=caa6b6008fe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-10-28 12:00:00.0; Final: 2017-10-28 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=802fab562631e510VgnVCM2000001f4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-11-25 12:00:00.0; Final: 2017-11-25 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2e4fab562631e510VgnVCM2000001f4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-11-23 18:00:00.0; Final: 2017-11-23 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8ca421dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-11-17 18:00:00.0; Final: 2017-11-17 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=465098df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-12-01 18:00:00.0; Final: 2017-12-01 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=97cdeeb6482ee510VgnVCM1000001d4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-12-16 12:00:00.0; Final: 2017-12-16 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2e01ab562631e510VgnVCM2000001f4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-11-02 18:00:00.0; Final: 2017-11-02 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=736298df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-11-03 18:00:00.0; Final: 2017-11-03 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b797562d96e0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-12-14 18:00:00.0; Final: 2017-12-14 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d11598df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-12-12 18:00:00.0; Final: 2017-12-12 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=16c6bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El pequeño país con Victoria; Inicio: 2017-12-13 18:00:00.0; Final: 2017-12-13 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=953fbc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: El sol y la luna con Luis Alberto Suárez; Inicio: 2017-10-27 19:00:00.0; Final: 2017-10-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=08420c39782fe510VgnVCM1000001d4a900aRCRD
#
# Titulo: El tiempo real; Inicio: 2017-10-24 11:00:00.0; Final: 2017-10-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=879d062967d1a510VgnVCM2000001f4a900aRCRD
#
# Titulo: El viaje de Arlo; Inicio: 2017-10-19 18:00:00.0; Final: 2017-10-19 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c982259bcecbe510VgnVCM1000001d4a900aRCRD
#
# Titulo: Escenarios de novela negra en Suecia; Inicio: 2017-11-02 00:00:00.0; Final: 2017-11-30 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8020f329f4799510VgnVCM2000001f4a900aRCRD
#
# Titulo: Escritura creativa: relato fantástico; Inicio: 2017-10-03 18:00:00.0; Final: 2018-05-29 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0e888c94a715e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Especial Día de Halloween; Inicio: 2017-10-31 18:00:00.0; Final: 2017-10-31 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2c5b7a206c9ae510VgnVCM1000001d4a900aRCRD
#
# Titulo: Especial Día de la Biblioteca; Inicio: 2017-10-24 18:00:00.0; Final: 2017-10-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a4aa7a206c9ae510VgnVCM1000001d4a900aRCRD
#
# Titulo: Estimulación cognitiva; Inicio: 2017-10-26 11:00:00.0; Final: 2017-10-26 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=64e0062967d1a510VgnVCM2000001f4a900aRCRD
#
# Titulo: Exposición de microrrelatos: 'Microteca'; Inicio: 2017-10-16 00:00:00.0; Final: 2017-11-30 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a639e7a9c556a510VgnVCM2000001f4a900aRCRD
#
# Titulo: Exposición: Las palabras llegaron con la cerámica; Inicio: 2017-06-28 00:00:00.0; Final: 2017-10-29 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=74275120139ec510VgnVCM1000001d4a900aRCRD
#
# Titulo: Gloriadías en el Día de la Biblioteca; Inicio: 2017-10-24 18:00:00.0; Final: 2017-10-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a95e9bd281cde510VgnVCM1000001d4a900aRCRD
#
# Titulo: Heroes Comic Con en Biblioteca Buenavista; Inicio: 2017-11-22 18:00:00.0; Final: 2017-11-22 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8d7e88aef110f510VgnVCM1000001d4a900aRCRD
#
# Titulo: Heroes Comic Con en Biblioteca Gerardo Diego; Inicio: 2017-11-17 18:00:00.0; Final: 2017-11-17 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=802b88aef110f510VgnVCM1000001d4a900aRCRD
#
# Titulo: Heroes Comic Con en Biblioteca Miguel Delibes; Inicio: 2017-11-08 17:30:00.0; Final: 2017-11-08 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0751e04c3400f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Heroes Comic Con en Biblioteca Moratalaz; Inicio: 2017-10-20 17:30:00.0; Final: 2017-10-20 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=eddfe04c3400f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Heroes Comic Con en Biblioteca Vargas LLosa; Inicio: 2017-11-24 18:00:00.0; Final: 2017-11-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=843f88aef110f510VgnVCM1000001d4a900aRCRD
#
# Titulo: Historia del jardín; Inicio: 2017-10-27 11:30:00.0; Final: 2017-12-01 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0bed8f00c7a9e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Hora del cuento en la Biblioteca Gloria Fuertes; Inicio: 2017-10-18 18:00:00.0; Final: 2018-06-20 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=26c6b963436ee510VgnVCM1000001d4a900aRCRD
#
# Titulo: Hotel Transilvania 2; Inicio: 2017-10-31 19:00:00.0; Final: 2017-10-31 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=1f081fcc397ce510VgnVCM2000001f4a900aRCRD
#
# Titulo: Juntas emprendemos; Inicio: 2017-10-24 12:00:00.0; Final: 2017-10-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=bee42fc40f92f510VgnVCM1000001d4a900aRCRD
#
# Titulo: La casa de Tomasa y otras historias con Daniel Tornero; Inicio: 2017-11-29 18:00:00.0; Final: 2017-11-29 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=bff0b6008fe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: La casa de Tomasa y otras historias con Daniel Tornero; Inicio: 2017-11-28 18:00:00.0; Final: 2017-11-28 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=3b74b6008fe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: La Casa Encantada; Inicio: 2017-10-31 18:00:00.0; Final: 2017-10-31 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c023f6a3338ce510VgnVCM1000001d4a900aRCRD
#
# Titulo: La mística y la poesía visionaria; Inicio: 2017-10-19 19:00:00.0; Final: 2017-10-19 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=30befb0e07b0f510VgnVCM1000001d4a900aRCRD
#
# Titulo: La música en los relatos y cuentos; Inicio: 2017-10-20 19:00:00.0; Final: 2017-10-20 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=59f80303b23ce510VgnVCM1000001d4a900aRCRD
#
# Titulo: La noche del cazador; Inicio: 2017-10-27 18:00:00.0; Final: 2017-10-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0f4d8e9ce52ce510VgnVCM1000001d4a900aRCRD
#
# Titulo: La Panditeca; Inicio: 2017-10-02 18:00:00.0; Final: 2017-12-18 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d3f9fc25b365e510VgnVCM2000001f4a900aRCRD
#
# Titulo: La sal de la tierra; Inicio: 2017-10-23 19:00:00.0; Final: 2017-10-23 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=5e480303b23ce510VgnVCM1000001d4a900aRCRD
#
# Titulo: La teoría sexual en psicoanálisis; Inicio: 2017-11-07 19:00:00.0; Final: 2017-11-07 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=74c7ad685349e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Labyrinth con Face2face; Inicio: 2017-11-17 18:00:00.0; Final: 2017-11-17 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=5b7feeb6482ee510VgnVCM1000001d4a900aRCRD
#
# Titulo: Labyrinth con Face2face; Inicio: 2017-11-04 12:00:00.0; Final: 2017-11-04 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=7650ab562631e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Labyrinth con Face2face; Inicio: 2017-11-22 18:00:00.0; Final: 2017-11-22 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=10f6b6008fe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Labyrinth con Face2Face; Inicio: 2017-11-30 18:00:00.0; Final: 2017-11-30 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=13b4bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Las gallinas contadoras con Volvoreta; Inicio: 2017-11-15 17:30:00.0; Final: 2017-11-15 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=f45b121bd69be510VgnVCM1000001d4a900aRCRD
#
# Titulo: Las gallinas contadoras con Volvoreta; Inicio: 2017-11-16 17:30:00.0; Final: 2017-11-16 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0fe3f500d625e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Locución poética; Inicio: 2017-10-02 17:00:00.0; Final: 2017-12-18 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=95e38c94a715e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Los superescritores; Inicio: 2017-09-03 18:15:00.0; Final: 2017-12-19 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ebb006483206e510VgnVCM1000001d4a900aRCRD
#
# Titulo: MAD for Swing. Versión Balboa; Inicio: 2017-11-18 12:00:00.0; Final: 2017-11-18 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=807e92132359e510VgnVCM2000001f4a900aRCRD
#
# Titulo: MAD for Swing. Versión Blues; Inicio: 2017-12-09 12:00:00.0; Final: 2017-12-09 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a7ce92132359e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Madrid Río Camina; Inicio: 2017-10-26 17:00:00.0; Final: 2017-10-26 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ed1c611f8e05e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Makers Unite. Juguetrónica infantil; Inicio: 2017-12-04 18:00:00.0; Final: 2017-12-04 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=fd1024812658e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Makers Unite. Juguetrónica infantil; Inicio: 2017-11-13 18:00:00.0; Final: 2017-11-13 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=61ef24812658e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Makers Unite. Juguetrónica infantil; Inicio: 2017-10-23 17:30:00.0; Final: 2017-10-23 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=40bf24812658e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Maratón de cuentos; Inicio: 2017-10-24 18:00:00.0; Final: 2017-10-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6169cc89e6a1b510VgnVCM1000001d4a900aRCRD
#
# Titulo: Meditación Vipassana; Inicio: 2017-10-02 10:00:00.0; Final: 2018-05-28 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=602a98e47b15e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Mi diario con Cuarta Pared; Inicio: 2017-12-14 18:00:00.0; Final: 2017-12-14 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=770f98df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Museo de Historia del Ayuntamiento de Madrid; Inicio: 2017-12-15 10:30:00.0; Final: 2017-12-15 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6f8876290b8be510VgnVCM2000001f4a900aRCRD
#
# Titulo: Museo de Historia del Ayuntamiento de Madrid; Inicio: 2017-11-17 10:30:00.0; Final: 2017-11-17 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=4296eb2db18be510VgnVCM2000001f4a900aRCRD
#
# Titulo: Museo de Historia del Ayuntamiento de Madrid; Inicio: 2017-10-20 10:30:00.0; Final: 2017-10-20 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=3c25eb2db18be510VgnVCM2000001f4a900aRCRD
#
# Titulo: Perdidos en el belén con Alicia Mohino; Inicio: 2017-12-05 18:00:00.0; Final: 2017-12-05 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=36bfc686ebe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Poemario; Inicio: 2017-10-24 19:00:00.0; Final: 2017-10-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=e8b455252960f510VgnVCM1000001d4a900aRCRD
#
# Titulo: Poesía inicial; Inicio: 2017-10-09 18:30:00.0; Final: 2017-12-18 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=9ceac2d769cce510VgnVCM1000001d4a900aRCRD
#
# Titulo: Radio teatro. Audiodrama colectivo; Inicio: 2017-11-16 19:00:00.0; Final: 2017-11-16 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a69192132359e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Radio teatro. Audiodrama colectivo; Inicio: 2017-10-19 19:00:00.0; Final: 2017-10-19 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c59192132359e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Ratones de bibliotecas con Volvoreta; Inicio: 2017-12-14 17:30:00.0; Final: 2017-12-14 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=77f3f500d625e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Ratones de bibliotecas con Volvoreta; Inicio: 2017-12-13 17:30:00.0; Final: 2017-12-13 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0f0e121bd69be510VgnVCM1000001d4a900aRCRD
#
# Titulo: Reflexoterapia podal; Inicio: 2017-10-30 11:00:00.0; Final: 2017-10-30 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=acbbfb0e07b0f510VgnVCM1000001d4a900aRCRD
#
# Titulo: Reflexoterapia podal; Inicio: 2017-12-11 18:00:00.0; Final: 2017-12-11 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c906dd906cbee510VgnVCM1000001d4a900aRCRD
#
# Titulo: Réquiem de Mozart: Mito y misterio; Inicio: 2017-11-02 10:30:00.0; Final: 2017-11-02 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=896daf55a250f510VgnVCM1000001d4a900aRCRD
#
# Titulo: Reunión literaria: Tea rooms de Luisa Carnés; Inicio: 2017-11-02 18:00:00.0; Final: 2017-11-02 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=307e386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Risoterapia; Inicio: 2017-11-27 18:00:00.0; Final: 2017-11-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b3b71363d598a510VgnVCM1000001d4a900aRCRD
#
# Titulo: Serena de Pilar Fernández Chamorro; Inicio: 2017-10-19 19:00:00.0; Final: 2017-10-19 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=37bd7b9b7b51f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Sexualidad para mujeres.; Inicio: 2017-12-04 19:00:00.0; Final: 2017-12-18 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0a40ddacea99e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Snowball con Face2face; Inicio: 2017-10-19 18:00:00.0; Final: 2017-10-19 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2699c686ebe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Snowball con Face2face; Inicio: 2017-10-27 18:00:00.0; Final: 2017-10-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=1213bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# ...
#
# Titulo: Snowball con Face2face; Inicio: 2017-11-18 12:00:00.0; Final: 2017-11-18 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=7d80ab562631e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Snowball con Face2face; Inicio: 2017-10-22 12:00:00.0; Final: 2017-10-22 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=4f8dab562631e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Snowball con Face2Face; Inicio: 2017-10-24 18:00:00.0; Final: 2017-10-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d206bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Solo; Inicio: 2017-10-23 19:00:00.0; Final: 2017-10-23 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=e681883723f2f510VgnVCM1000001d4a900aRCRD
#
# Titulo: Taller de conversación en francés. B1/B2; Inicio: 2017-10-18 19:00:00.0; Final: 2017-12-13 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c3da8f00c7a9e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Taller de conversación en francés. C1/C2; Inicio: 2017-10-19 19:00:00.0; Final: 2017-12-14 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=5d2b8f00c7a9e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Taller de Copto; Inicio: 2017-10-04 19:30:00.0; Final: 2018-01-31 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b19eacd02307e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller de Halloween; Inicio: 2017-10-30 18:00:00.0; Final: 2017-10-30 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ecc3e52ec152f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller de música; Inicio: 2017-11-06 11:00:00.0; Final: 2017-11-20 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ac9dce1f039ae510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller de poesía; Inicio: 2017-10-04 18:30:00.0; Final: 2018-05-30 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=53df98e47b15e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Taller de poesía dirigido por Vicente Zaragoza; Inicio: 2017-10-17 18:00:00.0; Final: 2018-06-12 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d8a7e313af00f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller Heroes Comic Con en Biblioteca Aluche; Inicio: 2017-11-22 18:00:00.0; Final: 2017-11-22 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=67ff386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller Heroes Comic Con en Biblioteca Aluche; Inicio: 2017-11-24 18:00:00.0; Final: 2017-11-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0420386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller Heroes Comic Con en Biblioteca Ángel González; Inicio: 2017-10-20 18:00:00.0; Final: 2017-10-20 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d5fb386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller Heroes Comic Con en Biblioteca Ángel González; Inicio: 2017-10-25 18:00:00.0; Final: 2017-10-25 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=88dc386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller Heroes Comic Con en Biblioteca Ángel González; Inicio: 2017-10-27 18:00:00.0; Final: 2017-10-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=381d386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller Heroes Comic Con en Biblioteca Gabriel García Márquez; Inicio: 2017-11-08 17:30:00.0; Final: 2017-11-08 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=230e386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller Heroes Comic Con en Biblioteca Gabriel García Márquez; Inicio: 2017-11-15 17:30:00.0; Final: 2017-11-15 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=081f386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller Heroes Comic Con en Biblioteca José Hierro; Inicio: 2017-11-03 18:00:00.0; Final: 2017-11-03 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=e28d386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller Heroes Comic Con en Biblioteca José Hierro; Inicio: 2017-11-10 18:00:00.0; Final: 2017-11-10 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8d4e386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller Heroes Comic Con en Biblioteca Mario Vargas Llosa; Inicio: 2017-11-10 18:00:00.0; Final: 2017-11-10 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a6be386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller Heroes Comic Con en Biblioteca Miguel Delibes; Inicio: 2017-11-03 18:00:00.0; Final: 2017-11-03 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6cad386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller Heroes Comic Con en Biblioteca Miguel Delibes; Inicio: 2017-10-27 18:00:00.0; Final: 2017-10-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=5d3d386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller Heroes Comic Con en Biblioteca Miguel Delibes; Inicio: 2017-10-20 18:00:00.0; Final: 2017-10-20 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=188c386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Taller sobre ópera; Inicio: 2017-03-21 18:30:00.0; Final: 2018-01-01 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=eb8e3793608da510VgnVCM2000001f4a900aRCRD
#
# Titulo: Tan diferentes y tan iguales; Inicio: 2017-12-12 18:00:00.0; Final: 2017-12-12 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=4f9e21dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Tan diferentes y tan iguales con Nelson Calderón; Inicio: 2017-12-05 18:00:00.0; Final: 2017-12-05 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a5c4b6008fe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Tatuajes en el alma con Fernando J. Medina; Inicio: 2017-10-20 19:00:00.0; Final: 2017-10-20 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d9220c39782fe510VgnVCM1000001d4a900aRCRD
#
# Titulo: Te receto un libro con Alejandro Marcos; Inicio: 2017-10-27 19:00:00.0; Final: 2017-10-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=faa4386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Bruno Galindo; Inicio: 2017-10-25 19:00:00.0; Final: 2017-10-25 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6e63386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Chiki Fabregat; Inicio: 2017-10-27 19:00:00.0; Final: 2017-10-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=9d34386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Elvira Navarro; Inicio: 2017-10-25 11:00:00.0; Final: 2017-10-25 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6633386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Elvira Navarro; Inicio: 2017-10-26 19:00:00.0; Final: 2017-10-26 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=08d3386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Enrique Valladares; Inicio: 2017-10-25 12:00:00.0; Final: 2017-10-25 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8053386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Ignacio Ferrando; Inicio: 2017-10-27 19:00:00.0; Final: 2017-10-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d064386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Inés Mendoza; Inicio: 2017-10-25 19:00:00.0; Final: 2017-10-25 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c8f3386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Javier Fonseca; Inicio: 2017-10-28 11:00:00.0; Final: 2017-10-28 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=51d4386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Javier Sagarna; Inicio: 2017-10-23 11:00:00.0; Final: 2017-10-23 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a392386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Jordi Costa; Inicio: 2017-10-24 11:00:00.0; Final: 2017-10-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2ba2386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Juan Carlos Márquez; Inicio: 2017-10-26 19:00:00.0; Final: 2017-10-26 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=3b14386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Lara Moreno; Inicio: 2017-10-26 19:30:00.0; Final: 2017-10-26 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b4b3386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Laura M. Belli; Inicio: 2017-10-25 11:00:00.0; Final: 2017-10-25 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=e213386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Luisge Martín; Inicio: 2017-10-24 19:00:00.0; Final: 2017-10-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=bbd2386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Marcelo Luján; Inicio: 2017-10-24 19:00:00.0; Final: 2017-10-24 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0713386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Te receto un libro con Marta Sanz; Inicio: 2017-10-29 12:00:00.0; Final: 2017-10-29 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2df4386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Terremotos; Inicio: 2017-11-07 18:30:00.0; Final: 2017-11-07 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b3fc3b851810f510VgnVCM1000001d4a900aRCRD
#
# Titulo: Tiña Periña con Roberto Mezquita; Inicio: 2017-12-05 18:00:00.0; Final: 2017-12-05 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=7f71bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Tiña Periña con Roberto Mezquita; Inicio: 2017-10-25 18:00:00.0; Final: 2017-10-25 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=dc8221dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Tiña periña con Roberto Mezquita; Inicio: 2017-11-04 12:00:00.0; Final: 2017-11-04 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=9bcdab562631e510VgnVCM2000001f4a900aRCRD
#
# Titulo: Tiña Periña con Roberto Mezquita; Inicio: 2017-12-15 18:00:00.0; Final: 2017-12-15 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2b68c686ebe0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Tiña Periña con Roberto Mezquita; Inicio: 2017-10-19 18:00:00.0; Final: 2017-10-19 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b5f398df8ed0e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Tiña Periña con Roberto Mezquita; Inicio: 2017-10-30 18:00:00.0; Final: 2017-10-30 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d80621dc4131e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Tiña Periña con Roberto Mezquita; Inicio: 2017-11-27 18:00:00.0; Final: 2017-11-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8c62bc1fc431e510VgnVCM1000001d4a900aRCRD
#
# Titulo: Un viaje de colores; Inicio: 2017-11-02 18:00:00.0; Final: 2017-11-02 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b69ba7fcd7a0f510VgnVCM2000001f4a900aRCRD
#
# Titulo: Una escritora en 'la edad de la razón'. Elena Fortún y su mundo; Inicio: 2017-03-01 00:00:00.0; Final: 2017-10-31 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6f57d53a024ab510VgnVCM1000001d4a900aRCRD
#
# Titulo: Una fiera en mi pecera. Para niños de 3 a 6 años; Inicio: 2017-10-25 18:00:00.0; Final: 2017-10-25 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d77f2431247eb510VgnVCM1000001d4a900aRCRD
#
# Titulo: Una ilustración de cuento; Inicio: 2017-10-02 00:00:00.0; Final: 2017-10-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=cd3fa4eda88ce510VgnVCM1000001d4a900aRCRD
#
# Titulo: Viajes por el armario del abuelo; Inicio: 2017-10-27 19:00:00.0; Final: 2017-10-27 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=539edd906cbee510VgnVCM1000001d4a900aRCRD
#
# Titulo: Vicálvaro: de pueblo a distrito; Inicio: 2017-01-02 00:00:00.0; Final: 2018-01-01 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=50f8630b16fd9510VgnVCM1000001d4a900aRCRD
#
# Titulo: XXXII Muestra del Libro Infantil y Juvenil 2017; Inicio: 2017-10-16 00:00:00.0; Final: 2017-10-29 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8ad4d540f22b9510VgnVCM1000001d4a900aRCRD
#
# Titulo: 'Cerebro y emociones: dos amigos desconocidos '; Inicio: 2017-10-26 18:00:00.0; Final: 2017-10-26 23:59:00.0; URL: http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ad0a1e736edbe510VgnVCM1000001d4a900aRCRD

# %% [markdown]
# #### Normas de entrega
#
# * Fecha tope de entrega: 27/10/2017
# * La entrega se realizará subiendo al campus virtual un notebook de Jupyter con la solución. El archivo tendrá como nombre FormatosI_GrupoX donde X será el número de grupo correspondiente.
